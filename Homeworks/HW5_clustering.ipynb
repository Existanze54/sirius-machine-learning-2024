# %% [markdown]
# <a href="https://colab.research.google.com/github/Existanze54/sirius-machine-learning-2024/blob/main/Homeworks/HW5_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#    ## Основные алгоритмы машинного обучения
#
# ## Домашнее задание 5
#
# ### Кластеризация. K-means.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Задача

# %% [markdown]
# Имеется цветное изображение цветка с разрешением `640x427` пикселей с названием `flower.png`. Загрузим это изображние в переменную `img` в виде трехмерного массива чисел:

# %%
img = plt.imread("flower.png")[:,:,:3]

# %%
_ = plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (427, 640, 3)

# %% [markdown]
# Цвет каждого пикселя задается трехмерным вектором в пространстве `RGB`. Это наши признаки.

# %%
print(img[400, 500])
# Out:
# [0.04313726 0.12156863 0.11372549]

# %% [markdown]
# То есть каждому пикселю соответствует тройка чисел `(r, g, b)` - интенсивности основных цветов, соответственно, красного, зеленого и синего.

# %% [markdown]
# __Преобразуйте массив в двумерный__. Первая координата должна соответствовать номер точки, вторая - ее признакам. То есть размерность преобразованного массива должна быть `(640x427=273280, 3)`.

# %%
#X = ...
#assert(X.shape == (273280, 3))

# %% [markdown]
# __Запустите кластеризацию__ на наших преобразованных данных с помощью метода k-средних (`sklearn.cluster.KMeans`) для числа кластеров, например, равного $6$.

# %%
#cls = KMeans(...)
#y_pred = cls.fit_predict(X)

# %% [markdown]
# Извлеките рассчитанные __координаты центроидов__ (аттрибут `cluster_centers_` объекта класса `KMeans`).

# %%
#centroids = ...

# %% [markdown]
# Наши центроиды - цвета в пространстве RGB. Можно их нарисовать:

# %%
_ = plt.imshow([centroids])

# %% [markdown]
# По матрице `X` __постройте матрицу `Y`__, в которой координаты (цвета) каждой точки заменены на координаты соответствующего центроида.

# %%
#Y = ...

# %% [markdown]
# Визуализируем результат:

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,15))
_ = ax1.imshow(np.array(Y).reshape(img.shape))
_ = ax2.imshow(img)

# %% [markdown]
# __Поэкспериментируйте с разным числом кластеров__. Начиная с какого числа кластеров, на Ваш взгляд, кластеризованное изображение цветка становится очень похожим на оригинал?

# %%
# Попробуйте разные значения количества кластеров
